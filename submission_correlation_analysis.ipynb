# %%
import pandas as pd

# %%
df1=pd.read_csv('xx') # fe submission
df2=pd.read_csv('xx') # tabnet submission
df3=pd.read_csv('xx') # transfer submission
df4=pd.read_csv('xx') # sep submission

# %%
df1.head()
# Out:
#          sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# 0  id_0004d9e33                     0.001237                0.002055
# 1  id_001897cda                     0.000839                0.001538
# 2  id_002429b5b                     0.000000                0.000000
# 3  id_00276f245                     0.001188                0.001317
# 4  id_0027f1083                     0.002060                0.001755
#
#    acat_inhibitor  acetylcholine_receptor_agonist  \
# 0        0.002935                        0.014543
# 1        0.003037                        0.004305
# 2        0.000000                        0.000000
# 3        0.002203                        0.011103
# 4        0.002549                        0.015119
#
#    acetylcholine_receptor_antagonist  acetylcholinesterase_inhibitor  \
# 0                           0.019623                        0.005624
# 1                           0.002430                        0.002545
# ...

# %%
df1.drop('sig_id', axis=1, inplace=True)

# %%
df1.head()
# Out:
#    5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  acat_inhibitor  \
# 0                     0.001237                0.002055        0.002935
# 1                     0.000839                0.001538        0.003037
# 2                     0.000000                0.000000        0.000000
# 3                     0.001188                0.001317        0.002203
# 4                     0.002060                0.001755        0.002549
#
#    acetylcholine_receptor_agonist  acetylcholine_receptor_antagonist  \
# 0                        0.014543                           0.019623
# 1                        0.004305                           0.002430
# 2                        0.000000                           0.000000
# 3                        0.011103                           0.015108
# 4                        0.015119                           0.017002
#
#    acetylcholinesterase_inhibitor  adenosine_receptor_agonist  \
# ...

# %%
df2.drop('sig_id', axis=1, inplace=True)
df3.drop('sig_id', axis=1, inplace=True)
df4.drop('sig_id', axis=1, inplace=True)

# %%
target_columns=df1.columns

# %%
def get_corr(predictions):
    mat = np.zeros((len(predictions), len(predictions)))
    for i in range(len(predictions)):
        for j in range(len(predictions)):
            print(f'Mean Correlation (column-wise) [Model {i}-{j}]: {predictions[i][target_columns].corrwith(predictions[j][target_columns]).mean()}')
            mat[i,j]=predictions[i][target_columns].corrwith(predictions[j][target_columns]).mean()

    return mat

# %%
predictions = [df1, df2, df3, df4]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
mat = get_corr(predictions)
mat_df = pd.DataFrame(mat, columns=[f'Model-{i}' for i in range(1, len(predictions)+1)])
plt.figure(figsize=(14,14))
sns.heatmap(mat_df, annot=True)
plt.show()
# Out:
# Mean Correlation (column-wise) [Model 0-0]: 1.0
# Mean Correlation (column-wise) [Model 0-1]: 0.8414420106278043
# Mean Correlation (column-wise) [Model 0-2]: 0.8323749501194415
# Mean Correlation (column-wise) [Model 0-3]: 0.9678719119757956
# Mean Correlation (column-wise) [Model 1-0]: 0.8414420106278043
# Mean Correlation (column-wise) [Model 1-1]: 1.0
# Mean Correlation (column-wise) [Model 1-2]: 0.8946000433067434
# Mean Correlation (column-wise) [Model 1-3]: 0.811634175641298
# Mean Correlation (column-wise) [Model 2-0]: 0.8323749501194415
# Mean Correlation (column-wise) [Model 2-1]: 0.8946000433067433
# Mean Correlation (column-wise) [Model 2-2]: 1.0
# Mean Correlation (column-wise) [Model 2-3]: 0.8062691148389394
# Mean Correlation (column-wise) [Model 3-0]: 0.9678719119757956
# Mean Correlation (column-wise) [Model 3-1]: 0.811634175641298
# Mean Correlation (column-wise) [Model 3-2]: 0.8062691148389394
# Mean Correlation (column-wise) [Model 3-3]: 1.0
